# %% [markdown]
# # IMERSÃO DADOS - ALURA
#
# ---

# %% [markdown]
# ### AULA 01: PYTHON, PANDAS E FARMÁCIA

# %% [markdown]
# Importando o banco de dados:

# %%
import pandas as pd
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# Cabeçalho:

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Total de linhas e colunas:

# %%
dados.shape
# Out:
# (23814, 877)

# %% [markdown]
# Analisando a coluna tratamento:

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# Analisando a coluna tempo:

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %% [markdown]
# Analisando a coluna dose:

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %% [markdown]
# Analisando a coluna droga:

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# Analisando a coluna g-0:

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# Distribuição da informação tratamento:

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# Distribuição da informação dose:

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# Proporção entre os dados tratamento:

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Proporção entre os dados dose:

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# Gráfico para os dados de tratamento:

# %%
dados['tratamento'].value_counts().plot.pie()

# %% [markdown]
# Gráficos para os dados de tempo:

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# Em quais linhas da coluna g-0, o valor está acima de 0:

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# Para mostrar novamente a tabela inicial sem o filtro:

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# **Desafio 01:** Investigar por que a classe tratamento é tão desbalanceada?

# %% [markdown]
# > Na classe tratamento notou-se um grande desbalanceamento pois, provavelmente o número de amostras com droga testados foram maiores que as de controle.

# %% [markdown]
# **Desafio 02:** Plotar as 5 últimas linhas da tabela

# %% [markdown]
# *   5 últimas linhas da tabela:

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# **Desafio 03:** Proporção das classes tratamento.

# %% [markdown]
# *   Proporção entre os dados tratamento:

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# **Desafio 04:** Quantas tipos de drogas foram investigados.

# %% [markdown]
# *   Quantidade de drogas investigadas:

# %%
dados['droga'].unique().shape[0]
# Out:
# 3289

# %% [markdown]
# **Desafio 05:** Procurar na documentação o método query(pandas).

# %% [markdown]
# >   pandas.DataFrame.query
# *   O método query (pandas) se encontra:
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %% [markdown]
# **Desafio 06:** Renomear as colunas tirando o hífen.

# %%
dados.columns = dados.columns.str.lower().str.replace('_', ' ')
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# **Desafio 07:** Deixar os gráficos bonitos. (Matplotlib.pyplot)

# %% [markdown]
# *   Formatando o gráfico:

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
dados['tempo'].value_counts().plot.bar(title = 'Quantidade por Tempo', fontsize=30)
dados['tempo'].value_counts().plot.bar(xlabel = 'Tempo', fontsize=15)
dados['tempo'].value_counts().plot.bar(ylabel = 'Quantidade', fontsize=15)
dados['tempo'].value_counts().plot.bar(color = ['purple', 'blue', 'green'])

# %% [markdown]
# **Desafio 08:** Resumo do que você aprendeu com os dados

# %% [markdown]
# > Nessa aula pude aprender como importar bancos de dados utilizando a biblioteca Pandas, a visualizas as cinco primeiras e últimas linhas de tabelas, como visualizar o total de linhas e colunas, como fazer a análise e distribuição das informações das colunas, como calcular a proporção dos dados, a elaboração de gráficos de pizza e de barras, como filtrar valores, renomear colunas e por fim em como formatar os gráficos.

# %% [markdown]
# ### AULA 02: ESTATÍSTICAS, VISUALIZAÇÃO DE DADOS E DISTRIBUIÇÕES

# %% [markdown]
# Renomeando a coluna droga por composto:

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Identificando os cinco elementos mais frequentes:

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %% [markdown]
# Filtrando a base de dados com a função query, informando a variável definida fora da função:

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# Importando a biblioteca Seaborn e plotando o gráfico:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %% [markdown]
# Quantidade de compostos aparecem na coluna g-0:

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %% [markdown]
# Identificando os valores mínimos e máximos:

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %% [markdown]
# Plotando o histograma para o gene g-0:

# %%
dados['g-0'].hist(bins = 100)

# %% [markdown]
# Plotando o histograma para o gene g-19:

# %%
dados['g-19'].hist(bins = 100)

# %% [markdown]
# Calculando e descrevendo algumas estatísticas importantes para o entendimento dos dados:

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %% [markdown]
# Analisando a base de dados g-0 e g-1 separadamente:

# %%
dados[['g-0', 'g-1']]
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %% [markdown]
# Analisando a base de dados g-0 e g-771:

# %%
dados.loc[:,'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %% [markdown]
# Transpondo linhas e colunas, e fazendo o histograma do valor médio dos genes:

# %%
dados.loc[:,'g-0':'g-771'].describe().T['mean'].hist(bins=30)

# %% [markdown]
# Transpondo linhas e colunas, e fazendo o histograma do valor mínimo dos genes:

# %%
dados.loc[:,'g-0':'g-771'].describe().T['min'].hist(bins=30)

# %% [markdown]
# Transpondo linhas e colunas, e fazendo o histograma do valor máximo dos genes:

# %%
dados.loc[:,'g-0':'g-771'].describe().T['max'].hist(bins=30)

# %% [markdown]
# Transpondo linhas e colunas, e fazendo o histograma do valor médio dos tipos celulares :

# %%
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins=50)

# %% [markdown]
# Plotando o boxplot para o gene g-0 (eixo x):

# %%
sns.boxplot(x='g-0' , data=dados)

# %% [markdown]
# Plotando o boxplot para o gene g-0 (eixos x e y rotacionados):

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g-0', x='tratamento' , data=dados)

# %% [markdown]
# **Desafio 01:** Ordenar o gráfico countplot

# %% [markdown]
# *   Ordenando o gráfico countplot:

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order=cod_compostos)
ax.set_title('Top 5 compostos')
plt.show()

# %% [markdown]
# **Desafio 02:** Melhorar a visualização alterando tamanho da fonte

# %% [markdown]
# *   Alterando a fonte e melhorando a visualização do gráfico countplot:

# %%
sns.set()         
plt.rc('axes', titlesize=16)    
plt.rc('axes', labelsize=16)    
plt.rc('xtick', labelsize=12)    
plt.rc('ytick', labelsize=12)    
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order=cod_compostos)
ax.set_title('Top 5 compostos')
ax.set_ylabel('Contagem')
ax.set_xlabel('Composto')
plt.show()

# %% [markdown]
# **Desafio 03:** Plotar os histogramas com seaborn

# %% [markdown]
# *   Refazendo os histogramas da aula 2 feito com o Pandas trocando pelo Seaborn:

# %%
sns.histplot(data=dados['g-0'],bins=100)

# %%
sns.histplot(data=dados['g-19'],bins=100)

# %%
sns.histplot(data=dados.loc[:,'g-0':'g-771'].describe().T['mean'],bins=30)

# %%
sns.histplot(data=dados.loc[:,'g-0':'g-771'].describe().T['min'],bins=30)

# %%
sns.histplot(data=dados.loc[:,'g-0':'g-771'].describe().T['max'],bins=30)

# %%
sns.histplot(data=dados.loc[:,'c-0':'c-99'].describe().T['mean'],bins=50)

# %% [markdown]
# **Desafio 04:** Estudar sobre as estatíticas retornadas no .describe()

# %% [markdown]
# > As análises estatísticas geradas pelo comando .describe() representam:
#
# *   count - contagem dos valores existentes não nulos da amostragem
# *   mean - média dos valores da amostragem
# *   std - desvio padrão (uniformidade) da amostragem
# *   min - valor mínimo da amostragem
# *   25% - primeiro quartil
# *   50% - mediana
# *   75% - terceiro quartil
# *   max - valor máximo da amostragem

# %% [markdown]
# **Desafio 05:** Refletir sobre a manipulação do tamanho das visualizações

# %% [markdown]
# > O tamanho das visualizações dos dados interfere diretamente na interpretação dos resultados. A legenda, a cor, a fonte, o espaçamento, entre outras manipulações podem alterar a interpretação dos dados feitas por quem irá receber aquelas visualizações. Estes dados distorcidos podem levar a erros e invalidar a análise.
#
# > Há fontes que utilizam visualizações de dados distorcidas com intuíto de chamar atenção de quem visualiza tais dados e até mesmo para induzí-los a uma análise que convenha e favorece uma determinada parte.

# %% [markdown]
# **Desafio 06:** Fazer outras análises com o boxplot e até com o histograma.

# %% [markdown]
# *   Plotando o grágico boxplot para o gene g-0 em relação a dose:

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g-0', x='dose' , data=dados)

# %% [markdown]
# *   Plotando o grágico boxplot para o gene g-0 em relação ao tempo:

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g-0', x='tempo' , data=dados)

# %% [markdown]
# *   Plotando o histograma para o gene g-0 analisando os tratamentos:

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=dados, x='g-0', bins=100, hue='tratamento')
plt.title('Contagem dos Valores de g-0')
plt.show()

# %% [markdown]
# **Desafio 07:** Resumo do que você aprendeu com os dados

# %% [markdown]
# > Nessa aula pude aprender como renomear colunas, como identificar elementos mais frequentes, o uso da função query, a importar a biblioteca Seaborn, a estilizar os gráficos, a calcular os valores mínimos e máximos, a plotar histogramas, a descrever algumas estatísticas importantes para o entendimento dos dados, transpor linhas e colunas, plotar o gráfico boxplot, a ordenar gráficos, plotar histogramas com seaborn e sobre a manipulação do tamanho dos dados.

# %% [markdown]
# ### AULA 03: CORRELAÇÕES E CAUSALIDADE

# %% [markdown]
# Cabeçalho:

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Tabela de frequências com a função crosstab:

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %% [markdown]
# Tabela de frequências multi-index com a função crosstab:

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# Normalizando a tabela:

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %% [markdown]
# Agregando uma métrica estatística associada a uma coluna:

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# Analisando a relação entre as colunas g-0 e g-3:

# %%
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %% [markdown]
# Plotando o gráfico de dispersão com scatterplot para g-0 e g-3:

# %%
sns.scatterplot(x='g-0', y = 'g-3', data=dados)

# %% [markdown]
# Plotando o gráfico de dispersão com scatterplot para g-0 e g-8:

# %%
sns.scatterplot(x='g-0', y = 'g-8', data=dados)

# %% [markdown]
# Linha de tendência:

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'})

# %% [markdown]
# Separando e plotadondo gráficos de acordo com as categorias da variável tratamento:

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %% [markdown]
# Correlação de todos os genes:

# %%
dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %% [markdown]
# Correlação dos genes g-0 à g-50:

# %%
corr = dados.loc[:,'g-0':'g-50'].corr()

# %% [markdown]
# Mapa de calor para a correlação dos genes g-0 à g-50:

# %%
import numpy as np


# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Mapa de calor para a correlação da viabilidade celular c-0 à c-50:

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# **Desafio 01:** Criar tabelas de frequência com pandas.groupby()

# %% [markdown]
# *   Tabela de frequências com a função pandas.groupby():

# %%
dados.groupby([dados['tratamento'],dados['tempo']]).mean()
# Out:
#                          g-0       g-1       g-2  ...      c-97      c-98      c-99
# tratamento   tempo                                ...
# com_controle 24    -0.119637 -0.340647  0.241432  ...  0.156828  0.241622  0.226405
#              48    -0.058786 -0.239302 -0.084079  ...  0.230692  0.325725  0.318349
#              72    -0.113108 -0.269072 -0.264560  ...  0.093519  0.290589  0.242814
# com_droga    24     0.241695 -0.126326  0.383142  ... -0.261335 -0.297678 -0.202118
#              48     0.318944 -0.075769  0.148428  ... -0.442619 -0.563793 -0.355848
#              72     0.269890 -0.037771 -0.024805  ... -0.567086 -0.740223 -0.490057
#
# [6 rows x 872 columns]

# %%
dados.groupby(['tratamento','dose','tempo'])['g-0'].mean().unstack(level=0)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# **Desafio 02:** Normalizar o crosstab pela coluna

# %% [markdown]
# *   Usando o crosstab e normalizando as colunas:

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# **Desafio 03:** Explorar outros agregadores

# %% [markdown]
# *   Outros agregadores além do mean utilizado na aula:

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g-0'], aggfunc='std')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.751395   1.461954
#      48         0.853396   1.693903
#      72         0.769294   1.458600
# D2   24         0.836626   1.044999
#      48         0.836845   1.315476
#      72         0.878041   1.451532

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g-0'], aggfunc='min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g-0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %% [markdown]
# **Desafio 04:** Explorar o melt

# %% [markdown]
# *   Utilizando o melt para comparar :

# %%
pd.melt(dados,id_vars=['dose'],value_vars=['g-0'])
# Out:
#       dose variable   value
# 0       D1      g-0  1.0620
# 1       D1      g-0  0.0743
# 2       D1      g-0  0.6280
# 3       D1      g-0 -0.5138
# 4       D2      g-0 -0.3254
# ...    ...      ...     ...
# 23809   D2      g-0  0.1394
# 23810   D2      g-0 -1.3260
# 23811   D2      g-0  0.3942
# 23812   D1      g-0  0.6660
# 23813   D1      g-0 -0.8598
#
# [23814 rows x 3 columns]

# %%
pd.melt(dados,id_vars=['tratamento'],value_vars=['g-0'])
# Out:
#          tratamento variable   value
# 0         com_droga      g-0  1.0620
# 1         com_droga      g-0  0.0743
# 2         com_droga      g-0  0.6280
# 3         com_droga      g-0 -0.5138
# 4         com_droga      g-0 -0.3254
# ...             ...      ...     ...
# 23809     com_droga      g-0  0.1394
# 23810     com_droga      g-0 -1.3260
# 23811  com_controle      g-0  0.3942
# 23812     com_droga      g-0  0.6660
# 23813     com_droga      g-0 -0.8598
#
# [23814 rows x 3 columns]

# %%
pd.melt(dados,id_vars=['tempo'],value_vars=['g-0'])
# Out:
#        tempo variable   value
# 0         24      g-0  1.0620
# 1         72      g-0  0.0743
# 2         48      g-0  0.6280
# 3         48      g-0 -0.5138
# 4         72      g-0 -0.3254
# ...      ...      ...     ...
# 23809     24      g-0  0.1394
# 23810     24      g-0 -1.3260
# 23811     48      g-0  0.3942
# 23812     24      g-0  0.6660
# 23813     72      g-0 -0.8598
#
# [23814 rows x 3 columns]

# %% [markdown]
# **Desafio 05:** Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos biológicos

# %% [markdown]
# *   Analisando a correlação entre G e C:

# %%
corr = dados.loc[:,'g-0':'c-99'].corr()

# %%
corr_celular_genes = corr.loc['g-0':'g-50','c-0':'c-50']

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular_genes, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.lmplot(data=dados, x='g-48', y='c-18', line_kws={'color': 'red'})

# %%
sns.lmplot(data=dados, x='g-37', y='c-18', line_kws={'color': 'red'})

# %% [markdown]
# **Desafio 06:** Estudar o código que plota a matriz de correlação (heatmap)

# %% [markdown]
# *   Correlação dos genes g-0 à g-50:

# %%
corr = dados.loc[:,'g-0':'g-50'].corr()

# %% [markdown]
# *   Gera uma máscara para o triângulo superior:

# %%
mask = np.triu(np.ones_like(corr, dtype=bool))

# %% [markdown]
# *   Configura a figura matplotlib:

# %%
f, ax = plt.subplots(figsize=(11, 9))

# %% [markdown]
# *   Gera um mapa de cores divergentes personalizado:

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# %% [markdown]
# *   Desenha o mapa de calor com a máscara e a proporção correta:

# %%
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# *   Resultado desses comandos:

# %%
mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Desafio 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# > Nessa aula pude aprender a criar uma tabela de frequências com a função crosstab, a normalizar a tabela, agregar métrica estatística associada a uma coluna, a analisar relação entre colunas, plotar gráfico de dispersão com scatterplot, a traçar linha de tendência, importar biblioteca numpy, fazer mapa de calor, Ta criar tabela de frequências com a função pandas.groupby() e a utilizar o melt.

# %% [markdown]
# ### AULA 04: MERGE E ANÁLISE DE RESULTADOS

# %% [markdown]
# Importando o banco de dados dos resultados:

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# Analisando os valores da acetylcholine:

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Analisando as informações dos resultados:

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %% [markdown]
# Somando as colunas exceto a coluna id:

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# Somando as linhas:

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %% [markdown]
# Dados dos resultados

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# Dados antes do resultado:

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Criando uma coluna chamada n_moa(número de moas ativos):

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)

# %% [markdown]
# Verificando se a coluna criada apresenta resultados diferentes de 0:

# %%
dados_resultados['n_moa'] != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %% [markdown]
# Criando as duas colunas:

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# Mesclando as informações e os resultados com o merge:

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# Analisando se no tratamento com controle algum moa foi ativado:

# %%
dados_combinados.query('tratamento == "com_controle"' )['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %% [markdown]
# Analisando se no tratamento com droga algum moa foi ativado:

# %%
dados_combinados.query('tratamento == "com_droga"' )['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %% [markdown]
# Plotando o boxplot para entender como está a distribuição dos dados:

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y= 'g-0', x='composto', hue='ativo_moa')

# %% [markdown]
# **Desafio 01:** Encontrar o top 10, das ações do MOA (inibidor, agonista...)

# %% [markdown]
# *   Top 10 ações do MOA

# %%
sufixos = [name.split('_')[-1] for name in contagem_moa.index]
contagem_sufixos = pd.DataFrame(data={'moa': sufixos, 'total': contagem_moa.values})
top10 = contagem_sufixos.groupby(by=['moa']).sum()['total'].sort_values(ascending=False)[:10]

# %%
plt.figure(figsize=(20,10))
ax= sns.barplot(y=top10.values, x=top10.index)
plt.title('Top 10 tipos de MOA', {'fontsize': 15})
plt.xlabel('MOA', {'fontsize': 12})
plt.ylabel('Quantidade', {'fontsize': 12})
plt.show()

# %% [markdown]
# **Desafio 02:** Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %% [markdown]
# *   Criando a coluna eh_controle:

# %%
dados_combinados['eh_controle'] = (dados['tratamento'] == 'com_controle')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True        False
#
# [5 rows x 880 columns]

# %% [markdown]
# **Desafio 03:** Criar três colunas para indicar o tempo 24, 48, 72

# %% [markdown]
# *   Criando três colunas para o tempo 24, 48, 72:

# %%
dados_combinados['24h'] = (dados_combinados['tempo'] == 24)
dados_combinados['48h'] = (dados_combinados['tempo'] == 48)
dados_combinados['72h'] = (dados_combinados['tempo'] == 72)
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle    24h    48h    72h
# 0  id_000644bb2  com_droga     24   D1  ...       False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...       False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False   True
#
# [5 rows x 883 columns]

# %% [markdown]
# **Desafio 04:** Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# **Desafio 05:** Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (escolher uma droga e comparar com controle)

# %% [markdown]
# *   Analisando detalhadamente tempo e dose:

# %%
plt.figure(figsize=(18,9))

plt.subplot(1,2,2)
sns.boxplot(data=dados.query('composto in @composto_principal'), 
            y='g-0', x='composto', hue='tempo');

plt.subplot(1,2,1)
sns.boxplot(data=dados.query('composto in @composto_principal'), 
            y='g-0', x='composto', hue='dose');

# %% [markdown]
# **Desafio 06:** Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %% [markdown]
# *   Verificando se ativa ou não o MOA:

# %%
ativos = dados_combinados.query('ativo_moa==True')
inativos = dados_combinados.query('ativo_moa==False & tratamento!="com_controle"')

compostos_inativos=inativos['composto'].values
combinacao=ativos.query('composto in @compostos_inativos')

len(combinacao)
# Out:
# 0

# %% [markdown]
# **Desafio 07:** Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes

# %% [markdown]
# *   Verificando se ativa ou não o MOA:

# %%
resumo=dados_combinados.query('ativo_moa==True')[['composto','dose','tempo','n_moa']]
diferentes=[]

for composto in resumo['composto'].unique():
  mudanca=False
  dftemp=resumo.query('composto==@composto')
  mudanca=dftemp['n_moa'].nunique() != 1
  if mudanca:
    diferentes.append(composto)
  
diferentes
# Out:
# []

# %% [markdown]
# **Desafio 08:** Resumo do que você aprendeu com os dados

# %% [markdown]
# > Nessa aula aprendi a analisar os dados dos resultados, a somar colunas e linhas, a criar colunas, a mesclar as informações experimentais com os resultados utilizando o merge e a analisar se algum MOA foi ativado tanto para o controle quando para a droga.

# %% [markdown]
# ### AULA 05: MACHINE LEARNING E SCIKIT LEARN

# %% [markdown]
# Analisando os dados combinados:

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle    24h    48h    72h
# 0  id_000644bb2  com_droga     24   D1  ...       False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...       False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False   True
#
# [5 rows x 883 columns]

# %% [markdown]
# Analisando os resultados dos dados:

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# Utilizando técnicas de Machine Learning para solucionar o problema
#
# ---

# %% [markdown]
# Importando o train_test_split do scikit learn:

# %%
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# Importando o LogisticRegression do scikit learn:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %% [markdown]
# Importando o DummyClassifier do scikit learn:

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %% [markdown]
# Entendendo a acurácia do DummyClassifier com o value_counts:

# %%
dados_combinados['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %% [markdown]
# Importando o DecisionTreeClassifier do scikit learn:

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %% [markdown]
# Importando o tree do scikit learn:

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15, 10), facecolor='k')
tree.plot_tree(modelo_arvore,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=['Não Ativado', 'Ativado'])

plt.show()

# %% [markdown]
# Buscando um resultado mais satisfatório:

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

teste=[]
treino=[]
for i in range(1,15):
    modelo_arvore = DecisionTreeClassifier(max_depth = i)
    modelo_arvore.fit(x_treino, y_treino)
    teste.append(modelo_arvore.score(x_teste, y_teste))
    treino.append(modelo_arvore.score(x_treino, y_treino))

# %% [markdown]
# Analisando a acurácia dos dados de teste:

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6204073063195465,
#  0.6210371614528658,
#  0.6180978374973756,
#  0.6210371614528658,
#  0.6206172580306529,
#  0.6151585135418853,
#  0.6136888515641402,
#  0.6111694310308629,
#  0.6000419903422213,
#  0.5987822800755827,
#  0.5947931975645602]

# %% [markdown]
# Analisando a acurácia os dados de treino:

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6605427536612252,
#  0.6707259461445594,
#  0.689570101307018,
#  0.7068395359823632,
#  0.7292530575822791,
#  0.7529788462547897,
#  0.7769670883418194,
#  0.7990656658443126]

# %% [markdown]
# Plotando gráfico lineplot para analisar os dados de teste e treino:

# %%
sns.lineplot(x=range(1,15), y = teste, label='teste')
sns.lineplot(x=range(1,15), y = treino, label='treino')

# %% [markdown]
# Aplicando o get_dummies e criando duas novas colunas binárias e análogas as categorias:

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %% [markdown]
# Utilizando o get_dummies para transformar as variáveis de interesse:

# %%
pd.get_dummies(dados_combinados, columns=['tratamento', 'dose', 'tempo'])
# Out:
#                  id   composto     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 887 columns]

# %%
dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
# Out:
#          tratamento  tempo dose     g-0  ...  eh_controle    24h    48h    72h
# 0         com_droga     24   D1  1.0620  ...        False   True  False  False
# 1         com_droga     72   D1  0.0743  ...        False  False  False   True
# 2         com_droga     48   D1  0.6280  ...        False  False   True  False
# 3         com_droga     48   D1 -0.5138  ...        False  False   True  False
# 4         com_droga     72   D2 -0.3254  ...        False  False  False   True
# ...             ...    ...  ...     ...  ...          ...    ...    ...    ...
# 23809     com_droga     24   D2  0.1394  ...        False   True  False  False
# 23810     com_droga     24   D2 -1.3260  ...        False   True  False  False
# 23811  com_controle     48   D2  0.3942  ...         True  False   True  False
# 23812     com_droga     24   D1  0.6660  ...        False   True  False  False
# 23813     com_droga     72   D1 -0.8598  ...        False  False  False   True
#
# ...

# %% [markdown]
# Ajustando o modelo com Random Forest:

# %%
from sklearn.ensemble import RandomForestClassifier


x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6875918538736091

# %% [markdown]
# **Desafio 01:** Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino,x_teste,y_treino,y_teste = train_test_split(x,y,test_size = 0.2,stratify=y,random_state=376)

modelo_KNeighborsClassifier = KNeighborsClassifier(n_neighbors=3)
modelo_KNeighborsClassifier.fit(x_treino,y_treino)
modelo_KNeighborsClassifier.score(x_teste,y_teste)
# Out:
# 0.6115893344530758

# %% [markdown]
# **Desafio 02:** Estude a documentação do Sklearn

# %% [markdown]
# > https://scikit-learn.org/stable/index.html

# %% [markdown]
# **Desafio 03:** Pesquisar o fluxograma 'Escolhendo o melhor modelo' choosing the right estimator

# %% [markdown]
# > https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
#
#
# > O choosing the right estimator é um fluxograma encontrado na documentação do Scikit learn que fornece aos usuários um guia básico sobre como abordar problemas e como utilizar o melhor modelo para os seus dados.

# %% [markdown]
# **Desafio 04:** Teste outras problemas (perguntas). 0, 1 ou +

# %%
x = dados_combinados.loc[:,'g-0':'c-99']
y=dados_combinados['tempo'].map({24:0,48:1,72:2})

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_rlogistica2 = LogisticRegression(solver='newton-cg')
modelo_rlogistica2.fit(x_treino, y_treino)
modelo_rlogistica2.score(x_teste, y_teste)
# Out:
# 0.686122191895864

# %% [markdown]
# **Desafio 05:** Escolha a droga mais utilizada e tente criar um modelo para prever está label

# %%
composto = dados_combinados['composto'].value_counts()
composto
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 161572520       1
# 35519ef6d       1
# 4055d26a8       1
# 7c1e00d49       1
# b046f598b       1
# Name: composto, Length: 3289, dtype: int64

# %%
dt = dados_combinados.query('composto in ["cacb2b860", "5628cb3ee"]')

# %%
x = dt.loc[:,'g-0':'g-10'] 
y = dt['composto'].map({'cacb2b860': 0, '5628cb3ee': 1})
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_rlogistica = LogisticRegression()
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.9637681159420289

# %% [markdown]
# **Desafio 06:** Resumo do que você aprendeu com os dados

# %% [markdown]
# > Nessa última aula da imersão dados aprendi a analisar os dados com modelos de machine learning importando o train_test_split, LogisticRegression, DummyClassifier, accuracy_score, DecisionTreeClassifier e o tree do scikit learn.
